# %% [markdown]
# <a href="https://colab.research.google.com/github/thenectartrips/AI_ML/blob/main/Lab02%2603_PiyushManiTripathi_590021763.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dataset={"Students_name":["A","B","C","D","E"],
         "Marks":[2,4,6,8,10]}

# %%
df=pd.DataFrame(dataset)

# %%
df
# Out:
#   Students_name  Marks
# 0             A      2
# 1             B      4
# 2             C      6
# 3             D      8
# 4             E     10

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
df["Marks"]=scalar.fit_transform(df[["Marks"]])

# %%
df
# Out:
#   Students_name     Marks
# 0             A -1.414214
# 1             B -0.707107
# 2             C  0.000000
# 3             D  0.707107
# 4             E  1.414214

# %%
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()
df["Marks"]=scalar.fit_transform(df[["Marks"]])

# %%
df
# Out:
#   Students_name  Marks
# 0             A   0.00
# 1             B   0.25
# 2             C   0.50
# 3             D   0.75
# 4             E   1.00

# %%
import pandas as pd
df  = pd.read_csv("/content/drive/MyDrive/AI_ML Experiments/train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
df['Ticket'].value_counts()
# Out:
# Ticket
# 347082              7
# 1601                7
# CA. 2343            7
# 3101295             6
# CA 2144             6
#                    ..
# PC 17590            1
# 17463               1
# 330877              1
# 373450              1
# STON/O2. 3101282    1
# Name: count, Length: 681, dtype: int64

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# G6             4
# C23 C25 C27    4
# B96 B98        4
# F2             3
# D              3
#               ..
# E17            1
# A24            1
# C50            1
# B42            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Sex'] = df['Sex'].map({'male':0, 'female':1})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Embarked'] = df['Embarked'].map({'S':0, 'C':1, 'Q':2})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
df.drop(columns=['Ticket'], inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.drop(columns=['PassengerId'], inplace=True)

# %%
df.drop(columns=['Cabin'], inplace=True)

# %%
df.drop(columns=['Name'], inplace=True)

# %%
df.drop(columns=['Embarked'], inplace=True)

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0           0       3    0  22.0      1      0   7.2500
# 1           1       1    1  38.0      1      0  71.2833
# 2           1       3    1  26.0      0      0   7.9250
# 3           1       1    1  35.0      1      0  53.1000
# 4           0       3    0  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 886         0       2    0  27.0      0      0  13.0000
# 887         1       1    1  19.0      0      0  30.0000
# 888         0       3    1   NaN      1      2  23.4500
# 889         1       1    0  26.0      0      0  30.0000
# 890         0       3    0  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df['Fare'].value_counts()
# Out:
# Fare
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 13.8583     1
# 50.4958     1
# 5.0000      1
# 9.8458      1
# 10.5167     1
# Name: count, Length: 248, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Survived' , data=df)
plt.title("Survived Count")
plt.show()

# %%
df[df['Survived'] == 1]['Sex'].value_counts()
# Out:
# Sex
# 1    233
# 0    109
# Name: count, dtype: int64

# %%
df[df['Survived'] == 0]['Sex'].value_counts()
# Out:
# Sex
# 0    468
# 1     81
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(
    x='Sex',
    data=df[df['Survived']==1]
)
plt.title("Numbers of Individuals by Gender")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(
    x='Pclass',
    data=df[df['Survived']==1]
)
plt.title("Numbers of Individuals by Pclass")
plt.show()

# %%
df[df['Survived'] == 1]['Pclass'].value_counts()
# Out:
# Pclass
# 1    136
# 3    119
# 2     87
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(
    x='Age',
    data=df[df['Survived']==1]
)
plt.title("Numbers of Individuals by Age")
plt.show()

# %%
df[df['Survived'] == 1]['Age'].value_counts()
# Out:
# Age
# 24.00    15
# 36.00    11
# 35.00    11
# 22.00    11
# 27.00    11
#          ..
# 0.67      1
# 43.00     1
# 11.00     1
# 0.42      1
# 47.00     1
# Name: count, Length: 65, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survived by Gender (Total Vs Survived)")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title="Survived" , labels=["No" , "Yes"])
plt.show()

# %%
df_encoded = pd.get_dummies(
    df,
    columns=['Sex'],
    drop_first=True
)

# %%
features_X  = ['Pclass' , 'Age']
target_y = ['Survived']

# %%
train_X=df[features_X]
train_y=df[target_y]

# %%
print("train_X:")
display(train_X)
# Out:
# train_X:
#      Pclass   Age
# 0         3  22.0
# 1         1  38.0
# 2         3  26.0
# 3         1  35.0
# 4         3  35.0
# ..      ...   ...
# 886       2  27.0
# 887       1  19.0
# 888       3   NaN
# 889       1  26.0
# 890       3  32.0
#
# [891 rows x 2 columns]

# %%
print("train_y:")
display(train_y)
# Out:
# train_y:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
df['Age'].fillna(df['Age'].mean(),inplace = True)
train_X = df[features_X]
train_y = df[target_y]
model = LogisticRegression(max_iter=1000)
model.fit(train_X, train_y)
# Out:
# /tmp/ipython-input-1608364620.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace = True)
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score
train_pred_y = model.predict(train_X)
train_accuracy = accuracy_score(train_y, train_pred_y)
print(f'Training Accuracy: {train_accuracy:.2%}')
# Out:
# Training Accuracy: 70.26%

# %%
import numpy as np
import pandas as pd # Import pandas
print("Enter Passenger Details")
Pclass = int(input("Passenger Class (1/2/3) : "))
age = float(input("Age :"))
# Create a DataFrame with named columns for prediction
input_data = pd.DataFrame([[Pclass , age]], columns=['Pclass', 'Age'])
prediction = model.predict(input_data)
if prediction[0] == 1:
  print("Prediction: Passenger Survived")
else:
  print("Prediction: Passenger Not Survived")
# Out:
# Enter Passenger Details
# Passenger Class (1/2/3) : 1
# Age :20
# Prediction: Passenger Survived
